# %%
x = int(input("enter any number: "))
if x%2 == 0:
    print("even")
else:
    print("odd")
# Out:
# enter any number: 5
# odd

# %%
Jack = input("Jack,enter odd or even: ")
Jane = input("Jane,enter odd or even: ")
x = int(input("enter any number: "))
y = int(input("enter any number: "))
z = x+y
if z%2 == 0:
    print("player that chose even wins ")
else:
    print("player that chose odd wins ")
# Out:
# Jack,enter odd or even: even
# Jane,enter odd or even: odd
# enter any number: 4
# enter any number: 5
# player that chose odd wins

# %%
a =[1500,1600,1700,1800,1900,20000,80000,90000,100000,150000] 
Administration =[2500,3000,5000,7000,4500,3700,4000,6000,7800,9000]
Marketing_Spend =[890,900,980,600,650,350,700,400,300,500]
State =["New york","California","Florida","New York","Florida","New York","California","Florida","New York","California"]
Profit =[1000,2000,3000,4000,5000,6000,7000,8000,9000,10000]
cam = {'R & D Spend':a, 'Administration':Administration, 'Marketing Spend':Marketing_Spend, 'State':State, 'Profit':Profit}

# %%
cam
# Out:
# {'R & D Spend': [1500,
#   1600,
#   1700,
#   1800,
#   1900,
#   20000,
#   80000,
#   90000,
#   100000,
#   150000],
#  'Administration': [2500,
#   3000,
#   5000,
#   7000,
#   4500,
#   3700,
#   4000,
#   6000,
#   7800,
#   9000],
#  'Marketing Spend': [890, 900, 980, 600, 650, 350, 700, 400, 300, 500],
#  'State': ['New york',
#   'California',
#   'Florida',
#   'New York',
#   'Florida',
#   'New York',
#   'California',
#   'Florida',
#   'New York',
#   'California'],
#  'Profit': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]}

# %%
import pandas

# %%
dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
# ...

# %%
startup_companies = pandas.DataFrame(cam)

# %%
startup_companies
# Out:
#    R & D Spend  Administration  Marketing Spend       State  Profit
# 0         1500            2500              890    New york    1000
# 1         1600            3000              900  California    2000
# 2         1700            5000              980     Florida    3000
# 3         1800            7000              600    New York    4000
# 4         1900            4500              650     Florida    5000
# 5        20000            3700              350    New York    6000
# 6        80000            4000              700  California    7000
# 7        90000            6000              400     Florida    8000
# 8       100000            7800              300    New York    9000
# 9       150000            9000              500  California   10000

# %%
startup_companies.to_excel("algorithm.xlsx")

# %%
startup_companies.head(5)
# Out:
#    R & D Spend  Administration  Marketing Spend       State  Profit
# 0         1500            2500              890    New york    1000
# 1         1600            3000              900  California    2000
# 2         1700            5000              980     Florida    3000
# 3         1800            7000              600    New York    4000
# 4         1900            4500              650     Florida    5000

# %%
startup_companies.tail(5)
# Out:
#    R & D Spend  Administration  Marketing Spend       State  Profit
# 5        20000            3700              350    New York    6000
# 6        80000            4000              700  California    7000
# 7        90000            6000              400     Florida    8000
# 8       100000            7800              300    New York    9000
# 9       150000            9000              500  California   10000

# %%
pandas.read_excel("startup_companies.xlsx")
# Out:
#    Unnamed: 0  R & D Spend  Administration  Marketing Spend       State  \
# 0           0         1500            2500              890    New york
# 1           1         1600            3000              900  California
# 2           2         1700            5000              980     Florida
# 3           3         1800            7000              600    New York
# 4           4         1900            4500              650     Florida
# 5           5        20000            3700              350    New York
# 6           6        80000            4000              700  California
# 7           7        90000            6000              400     Florida
# 8           8       100000            7800              300    New York
# 9           9       150000            9000              500  California
#
#    Profit
# 0    1000
# 1    2000
# 2    3000
# 3    4000
# 4    5000
# 5    6000
# 6    7000
# 7    8000
# 8    9000
# 9   10000

# %%
startup_companies.columns
# Out:
# Index(['R & D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
a = int(input("enter distance in miles: "))
b = int(input("enter time in hours: "))
c = a/b
print(" The speed at which the car is travelling is,", c, 'miles/hour')
# Out:
# enter distance in miles: 50
# enter time in hours: 2
#  The speed at which the car is travelling is, 25.0 miles/hour
